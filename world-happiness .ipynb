# %%
# dependecies and set up
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
file = "Resources/world-happiness-report.csv"
df = pd.read_csv(file)
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.518            0.258
# 1                      0.850            0.584            0.237
# 2                      0.707            0.618            0.275
# 3                      0.731            0.611            0.267
# 4                      0.776            0.710            0.268

# %%
df.shape
# Out:
# (1949, 11)

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 167.6+ KB

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %%
df.rename({'Country name': 'Country', 'Life Ladder':'Ladder score', 'Log GDP per capita': 'GDP', 'Healthy life expectancy at birth': 'Life expectancy', 
          'Freedom to make life choices': 'Freedom', 'Perceptions of corruption': 'corruption'}, axis=1, inplace=True)
df.head()
# Out:
#        Country  year  Ladder score    GDP  Social support  Life expectancy  \
# 0  Afghanistan  2008         3.724  7.370           0.451            50.80
# 1  Afghanistan  2009         4.402  7.540           0.552            51.20
# 2  Afghanistan  2010         4.758  7.647           0.539            51.60
# 3  Afghanistan  2011         3.832  7.620           0.521            51.92
# 4  Afghanistan  2012         3.783  7.705           0.521            52.24
#
#    Freedom  Generosity  corruption  Positive affect  Negative affect
# 0    0.718       0.168       0.882            0.518            0.258
# 1    0.679       0.190       0.850            0.584            0.237
# 2    0.600       0.121       0.707            0.618            0.275
# 3    0.496       0.162       0.731            0.611            0.267
# 4    0.531       0.236       0.776            0.710            0.268

# %%
 df.drop(columns=['Positive affect', 'Negative affect'], axis=1, inplace=True)

# %%
print(df.shape)
print(df.columns)
# Out:
# (1949, 9)
# Index(['Country', 'year', 'Ladder score', 'GDP', 'Social support',
#        'Life expectancy', 'Freedom', 'Generosity', 'corruption'],
#       dtype='object')

# %%
for col in df.columns:
    print(col, df[col].nunique(), len(df))
# Out:
# Country 166 1949
# year 16 1949
# Ladder score 1553 1949
# GDP 1500 1949
# Social support 455 1949
# Life expectancy 828 1949
# Freedom 535 1949
# Generosity 609 1949
# corruption 572 1949

# %%
for var in df.columns:
    if df[var].isnull().sum()/len(df) > 0:
        print(var, df[var].isnull().mean().round(3))
# Out:
# GDP 0.018
# Social support 0.007
# Life expectancy 0.028
# Freedom 0.016
# Generosity 0.046
# corruption 0.056

# %%
df.isnull().sum()
# Out:
# Country              0
# year                 0
# Ladder score         0
# GDP                 36
# Social support      13
# Life expectancy     55
# Freedom             32
# Generosity          89
# corruption         110
# dtype: int64

# %%
df.tail()
# Out:
#        Country  year  Ladder score    GDP  Social support  Life expectancy  \
# 1944  Zimbabwe  2016         3.735  7.984           0.768             54.4
# 1945  Zimbabwe  2017         3.638  8.016           0.754             55.0
# 1946  Zimbabwe  2018         3.616  8.049           0.775             55.6
# 1947  Zimbabwe  2019         2.694  7.950           0.759             56.2
# 1948  Zimbabwe  2020         3.160  7.829           0.717             56.8
#
#       Freedom  Generosity  corruption
# 1944    0.733      -0.095       0.724
# 1945    0.753      -0.098       0.751
# 1946    0.763      -0.068       0.844
# 1947    0.632      -0.064       0.831
# 1948    0.643      -0.009       0.789

# %%
df.isnull().sum()
# Out:
# Country              0
# year                 0
# Ladder score         0
# GDP                 36
# Social support      13
# Life expectancy     55
# Freedom             32
# Generosity          89
# corruption         110
# dtype: int64

# %%
for var in df.columns:
    if df[var].isnull().sum()/len(df) > 0:
        print(var, df[var].isnull().mean().round(3))
# Out:
# GDP 0.018
# Social support 0.007
# Life expectancy 0.028
# Freedom 0.016
# Generosity 0.046
# corruption 0.056

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df1 = pd.read_csv("Resources/world-happiness-report-2021.csv")
df1.head()
# Out:
#   Country name Regional indicator  year  Ladder score  \
# 0      Finland     Western Europe  2021         7.842
# 1      Denmark     Western Europe  2021         7.620
# 2  Switzerland     Western Europe  2021         7.571
# 3      Iceland     Western Europe  2021         7.554
# 4  Netherlands     Western Europe  2021         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  ...  \
# 0                 10.775           0.954                     72.0  ...
# 1                 10.933           0.954                     72.7  ...
# 2                 11.117           0.942                     74.4  ...
# 3                 10.878           0.983                     73.0  ...
# 4                 10.932           0.942                     72.4  ...
#
#    Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# 0      -0.098                      0.186                      2.43
# 1       0.030                      0.179                      2.43
# 2       0.025                      0.292                      2.43
# 3       0.160                      0.673                      2.43
# 4       0.175                      0.338                      2.43
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# 3                             1.482                         1.172
# 4                             1.501                         1.079
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
# 3                                  0.772
# 4                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798
#
# [5 rows x 21 columns]

# %%
df1.isnull().sum().head()
# Out:
# Country name                      0
# Regional indicator                0
# year                              0
# Ladder score                      0
# Standard error of ladder score    0
# dtype: int64

# %%
df1.shape
# Out:
# (149, 21)

# %%
df1.drop(columns=['upperwhisker','Regional indicator', 'lowerwhisker','Explained by: Log GDP per capita', 'Explained by: Social support',
                  'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 
                  'Explained by: Freedom to make life choices', 'Explained by: Freedom to make life choices',
                  'Standard error of ladder score',
                  'Explained by: Generosity', 'Explained by: Generosity', 'Explained by: Perceptions of corruption',
                  'Dystopia + residual', 'Ladder score in Dystopia'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#   Country name  year  Ladder score  Logged GDP per capita  Social support  \
# 0      Finland  2021         7.842                 10.775           0.954
# 1      Denmark  2021         7.620                 10.933           0.954
# 2  Switzerland  2021         7.571                 11.117           0.942
# 3      Iceland  2021         7.554                 10.878           0.983
# 4  Netherlands  2021         7.464                 10.932           0.942
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.0                         0.949      -0.098
# 1                     72.7                         0.946       0.030
# 2                     74.4                         0.919       0.025
# 3                     73.0                         0.955       0.160
# 4                     72.4                         0.913       0.175
#
#    Perceptions of corruption
# 0                      0.186
# 1                      0.179
# 2                      0.292
# 3                      0.673
# 4                      0.338

# %%
df1.rename({'Country name': 'Country', 'Logged GDP per capita': 'GDP', 'Healthy life expectancy': 'Life expectancy', 
          'Freedom to make life choices': 'Freedom', 'Perceptions of corruption': 'corruption'}, axis=1, inplace=True)
df1.head()
# Out:
#        Country  year  Ladder score     GDP  Social support  Life expectancy  \
# 0      Finland  2021         7.842  10.775           0.954             72.0
# 1      Denmark  2021         7.620  10.933           0.954             72.7
# 2  Switzerland  2021         7.571  11.117           0.942             74.4
# 3      Iceland  2021         7.554  10.878           0.983             73.0
# 4  Netherlands  2021         7.464  10.932           0.942             72.4
#
#    Freedom  Generosity  corruption
# 0    0.949      -0.098       0.186
# 1    0.946       0.030       0.179
# 2    0.919       0.025       0.292
# 3    0.955       0.160       0.673
# 4    0.913       0.175       0.338

# %%
frames = [df, df1]
df2 = pd.concat(frames)
data = df2.set_index('Country')
data.head()
# Out:
#              year  Ladder score    GDP  Social support  Life expectancy  \
# Country
# Afghanistan  2008         3.724  7.370           0.451            50.80
# Afghanistan  2009         4.402  7.540           0.552            51.20
# Afghanistan  2010         4.758  7.647           0.539            51.60
# Afghanistan  2011         3.832  7.620           0.521            51.92
# Afghanistan  2012         3.783  7.705           0.521            52.24
#
#              Freedom  Generosity  corruption
# Country
# Afghanistan    0.718       0.168       0.882
# Afghanistan    0.679       0.190       0.850
# Afghanistan    0.600       0.121       0.707
# Afghanistan    0.496       0.162       0.731
# Afghanistan    0.531       0.236       0.776

# %%
df2.loc[(df2['year']>=2018)].tail()
# Out:
#          Country  year  Ladder score    GDP  Social support  Life expectancy  \
# 144      Lesotho  2021         3.512  7.926           0.787           48.700
# 145     Botswana  2021         3.467  9.782           0.784           59.269
# 146       Rwanda  2021         3.415  7.676           0.552           61.400
# 147     Zimbabwe  2021         3.145  7.943           0.750           56.201
# 148  Afghanistan  2021         2.523  7.695           0.463           52.493
#
#      Freedom  Generosity  corruption
# 144    0.715      -0.131       0.915
# 145    0.824      -0.246       0.801
# 146    0.897       0.061       0.167
# 147    0.677      -0.047       0.821
# 148    0.382      -0.102       0.924

# %%
corr_df = df2[['Ladder score','GDP', 'Social support', 'Life expectancy', 'Freedom', 'Generosity', 'corruption']]
corr_df.corr().round(2).style.background_gradient(cmap='gray')
# Out:
# <style  type="text/css" >
# #T_1c065_row0_col0,#T_1c065_row1_col1,#T_1c065_row2_col2,#T_1c065_row3_col3,#T_1c065_row4_col4,#T_1c065_row5_col5,#T_1c065_row6_col6{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_1c065_row0_col1{
#             background-color:  #d8d8d8;
#             color:  #000000;
#         }#T_1c065_row0_col2{
#             background-color:  #c3c3c3;
#             color:  #000000;
#         }#T_1c065_row0_col3{
#             background-color:  #cfcfcf;
#             color:  #000000;
#         }#T_1c065_row0_col4{
#             background-color:  #aeaeae;
#             color:  #000000;
#         }#T_1c065_row0_col5{
#             background-color:  #5c5c5c;
#             color:  #f1f1f1;
#         }#T_1c065_row0_col6{
#             background-color:  #080808;
#             color:  #f1f1f1;
#         }#T_1c065_row1_col0{
#             background-color:  #dadada;
#             color:  #000000;
#         }#T_1c065_row1_col2{
#             background-color:  #c1c1c1;
#             color:  #000000;
#         }#T_1c065_row1_col3,#T_1c065_row3_col1{
#             background-color:  #e3e3e3;
#             color:  #000000;
#         }#T_1c065_row1_col4{
#             background-color:  #939393;
#             color:  #000000;
#         }#T_1c065_row1_col5{
#             background-color:  #343434;
#             color:  #f1f1f1;
#         }#T_1c065_row1_col6{
#             background-color:  #161616;
#             color:  #f1f1f1;
#         }#T_1c065_row2_col0{
#             background-color:  #cccccc;
#             color:  #000000;
#         }#T_1c065_row2_col1{
#             background-color:  #c7c7c7;
#             color:  #000000;
#         }#T_1c065_row2_col3{
#             background-color:  #b6b6b6;
#             color:  #000000;
#         }#T_1c065_row2_col4{
#             background-color:  #999999;
#             color:  #000000;
#         }#T_1c065_row2_col5{
#             background-color:  #424242;
#             color:  #f1f1f1;
#         }#T_1c065_row2_col6{
#             background-color:  #2c2c2c;
#             color:  #f1f1f1;
#         }#T_1c065_row3_col0{
#             background-color:  #d3d3d3;
#             color:  #000000;
#         }#T_1c065_row3_col2{
#             background-color:  #b0b0b0;
#             color:  #000000;
#         }#T_1c065_row3_col4{
#             background-color:  #989898;
#             color:  #000000;
#         }#T_1c065_row3_col5{
#             background-color:  #3a3a3a;
#             color:  #f1f1f1;
#         }#T_1c065_row3_col6{
#             background-color:  #191919;
#             color:  #f1f1f1;
#         }#T_1c065_row4_col0{
#             background-color:  #ababab;
#             color:  #000000;
#         }#T_1c065_row4_col1{
#             background-color:  #888888;
#             color:  #000000;
#         }#T_1c065_row4_col2{
#             background-color:  #848484;
#             color:  #000000;
#         }#T_1c065_row4_col3{
#             background-color:  #8c8c8c;
#             color:  #000000;
#         }#T_1c065_row4_col5{
#             background-color:  #787878;
#             color:  #000000;
#         }#T_1c065_row4_col6,#T_1c065_row6_col0,#T_1c065_row6_col1,#T_1c065_row6_col2,#T_1c065_row6_col3,#T_1c065_row6_col4,#T_1c065_row6_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_1c065_row5_col0{
#             background-color:  #6d6d6d;
#             color:  #000000;
#         }#T_1c065_row5_col1{
#             background-color:  #3e3e3e;
#             color:  #f1f1f1;
#         }#T_1c065_row5_col2{
#             background-color:  #383838;
#             color:  #f1f1f1;
#         }#T_1c065_row5_col3{
#             background-color:  #414141;
#             color:  #f1f1f1;
#         }#T_1c065_row5_col4{
#             background-color:  #8a8a8a;
#             color:  #000000;
#         }#T_1c065_row5_col6{
#             background-color:  #222222;
#             color:  #f1f1f1;
#         }</style><table id="T_1c065_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Ladder score</th>        <th class="col_heading level0 col1" >GDP</th>        <th class="col_heading level0 col2" >Social support</th>        <th class="col_heading level0 col3" >Life expectancy</th>        <th class="col_heading level0 col4" >Freedom</th>        <th class="col_heading level0 col5" >Generosity</th>        <th class="col_heading level0 col6" >corruption</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c065_level0_row0" class="row_heading level0 row0" >Ladder score</th>
#                         <td id="T_1c065_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1c065_row0_col1" class="data row0 col1" >0.790000</td>
#                         <td id="T_1c065_row0_col2" class="data row0 col2" >0.710000</td>
#                         <td id="T_1c065_row0_col3" class="data row0 col3" >0.750000</td>
#                         <td id="T_1c065_row0_col4" class="data row0 col4" >0.530000</td>
#                         <td id="T_1c065_row0_col5" class="data row0 col5" >0.180000</td>
#                         <td id="T_1c065_row0_col6" class="data row0 col6" >-0.430000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c065_level0_row1" class="row_heading level0 row1" >GDP</th>
#                         <td id="T_1c065_row1_col0" class="data row1 col0" >0.790000</td>
#                         <td id="T_1c065_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_1c065_row1_col2" class="data row1 col2" >0.700000</td>
#                         <td id="T_1c065_row1_col3" class="data row1 col3" >0.850000</td>
#                         <td id="T_1c065_row1_col4" class="data row1 col4" >0.370000</td>
#                         <td id="T_1c065_row1_col5" class="data row1 col5" >-0.020000</td>
#                         <td id="T_1c065_row1_col6" class="data row1 col6" >-0.350000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c065_level0_row2" class="row_heading level0 row2" >Social support</th>
#                         <td id="T_1c065_row2_col0" class="data row2 col0" >0.710000</td>
#                         <td id="T_1c065_row2_col1" class="data row2 col1" >0.700000</td>
#                         <td id="T_1c065_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_1c065_row2_col3" class="data row2 col3" >0.620000</td>
#                         <td id="T_1c065_row2_col4" class="data row2 col4" >0.410000</td>
#                         <td id="T_1c065_row2_col5" class="data row2 col5" >0.050000</td>
#                         <td id="T_1c065_row2_col6" class="data row2 col6" >-0.220000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c065_level0_row3" class="row_heading level0 row3" >Life expectancy</th>
#                         <td id="T_1c065_row3_col0" class="data row3 col0" >0.750000</td>
#                         <td id="T_1c065_row3_col1" class="data row3 col1" >0.850000</td>
#                         <td id="T_1c065_row3_col2" class="data row3 col2" >0.620000</td>
#                         <td id="T_1c065_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_1c065_row3_col4" class="data row3 col4" >0.400000</td>
#                         <td id="T_1c065_row3_col5" class="data row3 col5" >0.010000</td>
#                         <td id="T_1c065_row3_col6" class="data row3 col6" >-0.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c065_level0_row4" class="row_heading level0 row4" >Freedom</th>
#                         <td id="T_1c065_row4_col0" class="data row4 col0" >0.530000</td>
#                         <td id="T_1c065_row4_col1" class="data row4 col1" >0.370000</td>
#                         <td id="T_1c065_row4_col2" class="data row4 col2" >0.410000</td>
#                         <td id="T_1c065_row4_col3" class="data row4 col3" >0.400000</td>
#                         <td id="T_1c065_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_1c065_row4_col5" clas

# %%
df2.shape
# Out:
# (2098, 9)

# %%
df2.isnull().sum()
# Out:
# Country              0
# year                 0
# Ladder score         0
# GDP                 36
# Social support      13
# Life expectancy     55
# Freedom             32
# Generosity          89
# corruption         110
# dtype: int64

# %% [markdown]
# ### Multiple Regression Model

# %%
# missing_col = [['GDP', 'Social support', 'Life expectancy', 'Freedom', 'Generosity', 'corruption']]
# for i in missing_col:
# #     df2.loc[df2.loc[:,i].isnull(),i]=df2.loc[:,i].mean()

# %%
data = df2.dropna(how='any',axis=0)
data.shape
# Out:
# (1861, 9)

# %%
data.isnull().sum()
# Out:
# Country            0
# year               0
# Ladder score       0
# GDP                0
# Social support     0
# Life expectancy    0
# Freedom            0
# Generosity         0
# corruption         0
# dtype: int64

# %%
x=pd.DataFrame(data[['GDP', 'Social support', 'Life expectancy', 'Freedom', 'Generosity', 'corruption']])
y=pd.DataFrame(data["Ladder score"])

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=.20)

# %%
# creating an object of LinearRegression class

LR = LinearRegression()
# fitting the training data
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(x_test)
y_pred

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  [-1.93499856]
# Coefficients:
#  [[ 0.35692283  2.33077386  0.02910917  1.0862528   0.68807234 -0.64422495]]

# %%
#filter the table using only the country at interest 

df3 = data.loc[['Italy', 'Japan', 'Australia', 'New Zealand', 'India', 'Peru', 'Finland', 'South Africa', 'United States']]
df3.head()
# Out:
#          year  Ladder score     GDP  Social support  Life expectancy  Freedom  \
# Country
# Italy    2005         6.854  10.703           0.928            71.90    0.802
# Italy    2007         6.574  10.727           0.912            72.26    0.684
# Italy    2008         6.780  10.711           0.880            72.44    0.543
# Italy    2009         6.334  10.652           0.880            72.62    0.701
# Italy    2010         6.354  10.666           0.872            72.80    0.738
#
#          Generosity  corruption
# Country
# Italy           NaN       0.944
# Italy         0.113       0.922
# Italy         0.049       0.946
# Italy         0.240       0.890
# Italy        -0.060       0.921

# %%
df3.shape
# Out:
# (139, 8)

# %%
df3.loc[(df3['year']>=2018)].head()
# Out:
#          year  Ladder score     GDP  Social support  Life expectancy  Freedom  \
# Country
# Italy    2018         6.517  10.650           0.913             73.6    0.650
# Italy    2019         6.445  10.655           0.838             73.8    0.709
# Italy    2020         6.488  10.563           0.890             74.0    0.718
# Italy    2021         6.483  10.623           0.880             73.8    0.693
# Japan    2018         5.794  10.623           0.886             75.0    0.773
#
#          Generosity  corruption
# Country
# Italy        -0.021       0.888
# Italy        -0.082       0.866
# Italy        -0.150       0.844
# Italy        -0.084       0.866
# Japan        -0.261       0.687

# %%
df3.shape
# Out:
# (139, 8)

# %%
#checking which columns has null value after combining the two datasets and filtering the tables using  

df3.isnull().sum()
# Out:
# year               0
# Ladder score       0
# GDP                0
# Social support     1
# Life expectancy    0
# Freedom            0
# Generosity         6
# corruption         1
# dtype: int64

# %%
corr_df = df3[['Ladder score','GDP', 'Social support', 'Life expectancy', 'Freedom', 'Generosity', 'corruption']]
corr_df.corr().style.background_gradient(cmap='gray')
# Out:
# <style  type="text/css" >
# #T_794df_row0_col0,#T_794df_row1_col1,#T_794df_row2_col2,#T_794df_row3_col3,#T_794df_row4_col4,#T_794df_row5_col5,#T_794df_row6_col6{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_794df_row0_col1{
#             background-color:  #e6e6e6;
#             color:  #000000;
#         }#T_794df_row0_col2{
#             background-color:  #dcdcdc;
#             color:  #000000;
#         }#T_794df_row0_col3{
#             background-color:  #cecece;
#             color:  #000000;
#         }#T_794df_row0_col4{
#             background-color:  #bebebe;
#             color:  #000000;
#         }#T_794df_row0_col5{
#             background-color:  #b0b0b0;
#             color:  #000000;
#         }#T_794df_row0_col6{
#             background-color:  #0a0a0a;
#             color:  #f1f1f1;
#         }#T_794df_row1_col0,#T_794df_row2_col1{
#             background-color:  #e9e9e9;
#             color:  #000000;
#         }#T_794df_row1_col2{
#             background-color:  #eaeaea;
#             color:  #000000;
#         }#T_794df_row1_col3{
#             background-color:  #d8d8d8;
#             color:  #000000;
#         }#T_794df_row1_col4{
#             background-color:  #a2a2a2;
#             color:  #000000;
#         }#T_794df_row1_col5{
#             background-color:  #989898;
#             color:  #000000;
#         }#T_794df_row1_col6{
#             background-color:  #272727;
#             color:  #f1f1f1;
#         }#T_794df_row2_col0{
#             background-color:  #e0e0e0;
#             color:  #000000;
#         }#T_794df_row2_col3,#T_794df_row5_col4{
#             background-color:  #b6b6b6;
#             color:  #000000;
#         }#T_794df_row2_col4{
#             background-color:  #9f9f9f;
#             color:  #000000;
#         }#T_794df_row2_col5{
#             background-color:  #838383;
#             color:  #000000;
#         }#T_794df_row2_col6{
#             background-color:  #262626;
#             color:  #f1f1f1;
#         }#T_794df_row3_col0{
#             background-color:  #d6d6d6;
#             color:  #000000;
#         }#T_794df_row3_col1{
#             background-color:  #dadada;
#             color:  #000000;
#         }#T_794df_row3_col2,#T_794df_row5_col0{
#             background-color:  #bababa;
#             color:  #000000;
#         }#T_794df_row3_col4{
#             background-color:  #9a9a9a;
#             color:  #000000;
#         }#T_794df_row3_col5{
#             background-color:  #878787;
#             color:  #000000;
#         }#T_794df_row3_col6{
#             background-color:  #313131;
#             color:  #f1f1f1;
#         }#T_794df_row4_col0{
#             background-color:  #bbbbbb;
#             color:  #000000;
#         }#T_794df_row4_col1{
#             background-color:  #929292;
#             color:  #000000;
#         }#T_794df_row4_col2{
#             background-color:  #8e8e8e;
#             color:  #000000;
#         }#T_794df_row4_col3,#T_794df_row5_col3{
#             background-color:  #828282;
#             color:  #000000;
#         }#T_794df_row4_col5{
#             background-color:  #a8a8a8;
#             color:  #000000;
#         }#T_794df_row4_col6,#T_794df_row6_col0,#T_794df_row6_col1,#T_794df_row6_col2,#T_794df_row6_col3,#T_794df_row6_col4,#T_794df_row6_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_794df_row5_col1{
#             background-color:  #999999;
#             color:  #000000;
#         }#T_794df_row5_col2{
#             background-color:  #868686;
#             color:  #000000;
#         }#T_794df_row5_col6{
#             background-color:  #292929;
#             color:  #f1f1f1;
#         }</style><table id="T_794df_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Ladder score</th>        <th class="col_heading level0 col1" >GDP</th>        <th class="col_heading level0 col2" >Social support</th>        <th class="col_heading level0 col3" >Life expectancy</th>        <th class="col_heading level0 col4" >Freedom</th>        <th class="col_heading level0 col5" >Generosity</th>        <th class="col_heading level0 col6" >corruption</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_794df_level0_row0" class="row_heading level0 row0" >Ladder score</th>
#                         <td id="T_794df_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_794df_row0_col1" class="data row0 col1" >0.848365</td>
#                         <td id="T_794df_row0_col2" class="data row0 col2" >0.785757</td>
#                         <td id="T_794df_row0_col3" class="data row0 col3" >0.716926</td>
#                         <td id="T_794df_row0_col4" class="data row0 col4" >0.533680</td>
#                         <td id="T_794df_row0_col5" class="data row0 col5" >0.528746</td>
#                         <td id="T_794df_row0_col6" class="data row0 col6" >-0.734708</td>
#             </tr>
#             <tr>
#                         <th id="T_794df_level0_row1" class="row_heading level0 row1" >GDP</th>
#                         <td id="T_794df_row1_col0" class="data row1 col0" >0.848365</td>
#                         <td id="T_794df_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_794df_row1_col2" class="data row1 col2" >0.867878</td>
#                         <td id="T_794df_row1_col3" class="data row1 col3" >0.775462</td>
#                         <td id="T_794df_row1_col4" class="data row1 col4" >0.341888</td>
#                         <td id="T_794df_row1_col5" class="data row1 col5" >0.386087</td>
#                         <td id="T_794df_row1_col6" class="data row1 col6" >-0.531867</td>
#             </tr>
#             <tr>
#                         <th id="T_794df_level0_row2" class="row_heading level0 row2" >Social support</th>
#                         <td id="T_794df_row2_col0" class="data row2 col0" >0.785757</td>
#                         <td id="T_794df_row2_col1" class="data row2 col1" >0.867878</td>
#                         <td id="T_794df_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_794df_row2_col3" class="data row2 col3" >0.581550</td>
#                         <td id="T_794df_row2_col4" class="data row2 col4" >0.317886</td>
#                         <td id="T_794df_row2_col5" class="data row2 col5" >0.265586</td>
#                         <td id="T_794df_row2_col6" class="data row2 col6" >-0.541386</td>
#             </tr>
#             <tr>
#                         <th id="T_794df_level0_row3" class="row_heading level0 row3" >Life expectancy</th>
#                         <td id="T_794df_row3_col0" class="data row3 col0" >0.716926</td>
#                         <td id="T_794df_row3_col1" class="data row3 col1" >0.775462</td>
#                         <td id="T_794df_row3_col2" class="data row3 col2" >0.581550</td>
#                         <td id="T_794df_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_794df_row3_col4" class="data row3 col4" >0.284125</td>
#                         <td id="T_794df_row3_col5" class="data row3 col5" >0.283942</td>
#                         <td id="T_794df_row3_col6" class="data row3 col6" >-0.462133</td>
#             </tr>
#             <tr>
#                         <th id="T_794df_level0_row4" class="row_heading level0 row4" >Freedom</th>
#                         <td id="T_794df_row4_col0" class="data row4 col0" >0.533680</td>
#                         <td id="T_794df_row4_col1" class="data row4 col1" >0.341888</td>
#                         <td id="T_794df_row4_col2" class="data row4 col2" >0.317886</td>
#                         <td id="T_794df_row4_col3" class="data row4 col3" >0.284125</td>
#                         <td id="T_794df_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_794df_row4_col5" class="data row4 col5" >0.481548</td>
#                         <td id="T_794df_row4_col6" class="data row4 col6" >-0.811538</td>
#             </tr>
#             <tr>
#                         <th id="T_794df_level0_row5" class="row_heading level0

# %%
X = df3[['GDP', 'Social support', 'Life expectancy', 'Freedom', 'Generosity', 'corruption']]
y = df3['Ladder score']

# %%
cnt = df3.reset_index().groupby(['Country']).count()
cnt
# Out:
#                year  Ladder score  GDP  Social support  Life expectancy  \
# Country
# Australia        15            15   15              15               15
# Finland          14            14   14              14               14
# India            16            16   16              16               16
# Italy            16            16   16              16               16
# Japan            16            16   16              16               16
# New Zealand      15            15   15              15               15
# Peru             15            15   15              15               15
# South Africa     16            16   16              16               16
# United States    16            16   16              15               16
#
#                Freedom  Generosity  corruption
# Country
# Australia           15          14          15
# Finland             14          14          14
# India               16          15          16
# Italy               16          15          16
# Japan               16          14          16
# New Zealand         15          15          15
# Peru                15          15          15
# South Africa        16          16          15
# United States       16          15          16

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-8a11d5d4a70e> in <module>
#       1 regr = linear_model.LinearRegression()
# ----> 2 regr.fit(X, y)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
